# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# **Task** **1**

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]

# %%
plt.plot(x, y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# **Task 2**

# %%
t = np.linspace(0, 10, 55)
f = np.cos(t)
plt.plot(t, f, color='green')
plt.title("Графики f(t)")
plt.xlabel("Значения t")
plt.ylabel("Значения f")
plt.axis([0.5, 9.5, -2.5, 2.5])
# Out:
# (0.5, 9.5, -2.5, 2.5)

# %% [markdown]
# **Task** **3**

# %%
x = np.linspace(-3, 3, 51)
y1 = [i**2 for i in x]
y2 = [2 * i + 0.5 for i in x]
y3 = [-3 * i - 1.5 for i in x]
y4 = np.sin(x)
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.set_size_inches(8, 6)
fig.subplots_adjust(wspace=0.3)
ax1, ax2, ax3, ax4 = ax.flatten()
ax1.plot(x, y1)
ax2.plot(x, y2)
ax3.plot(x, y3)
ax4.plot(x, y4)
ax1.axis([-5, 5, None, None])
# Out:
# (-5.0, 5.0, -0.45, 9.45)

# %% [markdown]
# **Task 4**

# %%
plt.style.use('fivethirtyeight')
cc = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/creditcard.csv", 
                 sep=",")
cc_vc = cc["Class"].value_counts()
cc_vc.plot(kind='bar')
plt.yscale(value="log")
plt.show()

# %% [markdown]
# немного не успел доделать, завершу сразу после вебинара
